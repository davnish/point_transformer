# %%
import pandas as pd

# %%
df180 = pd.read_csv('PCT_FPADV_1_180.csv')
df180
# Out:
#     train_loss  train_acc  val_loss   val_acc
# 0     0.179972   0.934802  0.281853  0.913388
# 1     0.165820   0.939080  0.277554  0.915436
# 2     0.162364   0.941146  0.264069  0.919058
# 3     0.159923   0.941563  0.251980  0.920200
# 4     0.171082   0.937963  0.283590  0.912744
# 5     0.164900   0.939752  0.276278  0.918898
# 6     0.158206   0.942410  0.256207  0.917420
# 7     0.158683   0.941968  0.277118  0.919701
# 8     0.154270   0.943561  0.283119  0.918237
# 9     0.167046   0.939745  0.278480  0.918249
# 10    0.158905   0.941708  0.273605  0.918840
# 11    0.163526   0.940210  0.276143  0.918970
# 12    0.153405   0.943701  0.261415  0.920925
# 13    0.152844   0.944163  0.271917  0.920505
# 14    0.151970   0.944336  0.274602  0.919646
# 15    0.152168   0.944187  0.273714  0.919861
# 16    0.149765   0.945255  0.260960  0.920885
# 17    0.149386   0.945044  0.261751  0.922419
# 18    0.146937   0.946024  0.267255  0.921349
# ...

# %%
df140 = pd.read_csv('PCT_FPADV_1_140.csv')

# %%
df140.drop(['Unnamed: 0.4', 'Unnamed: 0.3' ,'Unnamed: 0.2' ,'Unnamed: 0.1'	,'Unnamed: 0'], axis = 1, inplace = True)

# %%
df = pd.concat([df140, df180], axis = 0)
df
# Out:
#     train_loss  train_acc  val_loss   val_acc
# 0     0.986203   0.693584  0.789003  0.725190
# 1     0.568479   0.810413  0.671870  0.781180
# 2     0.465728   0.843745  0.466879  0.840902
# 3     0.402778   0.863207  0.413941  0.861119
# 4     0.388578   0.866464  0.384900  0.863995
# ..         ...        ...       ...       ...
# 35    0.202001   0.926183  0.257315  0.918239
# 36    0.172818   0.937388  0.242674  0.920921
# 37    0.158903   0.941819  0.263389  0.919845
# 38    0.154499   0.943234  0.259166  0.920787
# 39    0.158313   0.941952  0.267462  0.920486
#
# [180 rows x 4 columns]

# %%
df.to_csv('PCT_FPADV_1_180.csv', index = False)
